# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv("winequality-red.csv")
X_data = data[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']]
y_data = data['quality'] - 3

# %%
def report(y, pred):
    print(classification_report(y, pred, zero_division=0))
    ConfusionMatrixDisplay.from_predictions(y, pred)

# %% [markdown]
# ## SVM

# %%
pred = cross_val_predict(SVC(C=10000), X_data, y_data)
report(y_data, pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.00      0.00      0.00        53
#            2       0.62      0.75      0.68       681
#            3       0.54      0.52      0.53       638
#            4       0.41      0.29      0.34       199
#            5       0.00      0.00      0.00        18
#
#     accuracy                           0.56      1599
#    macro avg       0.26      0.26      0.26      1599
# weighted avg       0.53      0.56      0.54      1599

# %% [markdown]
# ## RandomForest

# %%
pred = cross_val_predict(RandomForestClassifier(n_estimators=50), X_data, y_data)
report(y_data, pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.25      0.02      0.04        53
#            2       0.64      0.74      0.69       681
#            3       0.54      0.58      0.56       638
#            4       0.50      0.30      0.38       199
#            5       1.00      0.11      0.20        18
#
#     accuracy                           0.59      1599
#    macro avg       0.49      0.29      0.31      1599
# weighted avg       0.57      0.59      0.57      1599

# %% [markdown]
# ## Decision Tree

# %%
pred = cross_val_predict(DecisionTreeClassifier(), X_data, y_data)
report(y_data, pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.08      0.10      0.09        10
#            1       0.12      0.15      0.13        53
#            2       0.60      0.57      0.58       681
#            3       0.45      0.45      0.45       638
#            4       0.32      0.34      0.33       199
#            5       0.18      0.17      0.17        18
#
#     accuracy                           0.47      1599
#    macro avg       0.29      0.30      0.29      1599
# weighted avg       0.48      0.47      0.48      1599

# %% [markdown]
# ## Naive Bayes

# %%
pred = cross_val_predict(GaussianNB(), X_data, y_data)
report(y_data, pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.10      0.12        10
#            1       0.08      0.09      0.08        53
#            2       0.66      0.65      0.66       681
#            3       0.52      0.47      0.49       638
#            4       0.35      0.48      0.40       199
#            5       0.09      0.06      0.07        18
#
#     accuracy                           0.53      1599
#    macro avg       0.31      0.31      0.31      1599
# weighted avg       0.54      0.53      0.53      1599

# %% [markdown]
# ## KNN

# %%
pred = cross_val_predict(KNeighborsClassifier(), X_data, y_data)
report(y_data, pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.05      0.02      0.03        53
#            2       0.50      0.58      0.54       681
#            3       0.40      0.43      0.42       638
#            4       0.34      0.18      0.23       199
#            5       0.00      0.00      0.00        18
#
#     accuracy                           0.44      1599
#    macro avg       0.22      0.20      0.20      1599
# weighted avg       0.42      0.44      0.42      1599
