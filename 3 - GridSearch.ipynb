# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_predict, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv("winequality-red.csv")
X_data = data[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']]
y_data = data['quality'] - 3

# %%
def report(y, pred):
    print(classification_report(y, pred, zero_division=0))
    ConfusionMatrixDisplay.from_predictions(y, pred)

# %% [markdown]
# ## RandomForest

# %%
params = {
    "n_estimators": [25, 50, 100],
    "max_depth": [None, 5, 10],
    "min_samples_split": [2, 3, 4, 5],
    "min_samples_leaf": [1, 2, 3, 4]
}

grid = GridSearchCV(RandomForestClassifier(), param_grid=params)
grid.fit(X_data, y_data)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'n_estimators': [25, 50, 100]})

# %%
grid.best_score_
# Out:
# 0.5997648902821316

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.073664      0.011713         0.004087        0.000601
# 1         0.133277      0.004034         0.006002        0.000391
# 2         0.284513      0.019890         0.011235        0.000624
# 3         0.072756      0.006811         0.003721        0.000119
# 4         0.129943      0.003784         0.006143        0.000458
# ..             ...           ...              ...             ...
# 139       0.102196      0.001209         0.005264        0.000053
# 140       0.207426      0.004673         0.009091        0.000234
# 141       0.052356      0.000509         0.003275        0.000103
# 142       0.101635      0.001734         0.005169        0.000194
# 143       0.201754      0.000497         0.009261        0.000654
#
#     param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0              None                      1                       2
# 1              None                      1                       2
# 2              None                      1                       2
# 3              None                      1                       3
# 4              None                      1                       3
# ..              ...                    ...                     ...
# 139              10                      4                       4
# 140              10                      4                       4
# 141              10                      4                       5
# 142              10                      4                       5
# 143              10                      4                       5
#
#     param_n_estimators                                             params  \
# 0                   25  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 1                   50  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 2                  100  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 3                   25  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 4                   50  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# ..                 ...                                                ...
# 139                 50  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 140                100  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 141                 25  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 142                 50  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 143                100  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.512500           0.550000           0.590625
# 1             0.537500           0.556250           0.606250
# 2             0.556250           0.562500           0.603125
# 3             0.487500           0.553125           0.571875
# 4             0.534375           0.546875           0.621875
# ..                 ...                ...                ...
# 139           0.546875           0.546875           0.631250
# 140           0.550000           0.571875           0.606250
# 141           0.546875           0.553125           0.615625
# 142           0.550000           0.568750           0.590625
# 143           0.556250           0.568750           0.612500
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.581250           0.583072         0.563489        0.029042
# 1             0.596875           0.576803         0.574736        0.025361
# 2             0.584375           0.583072         0.577864        0.016798
# 3             0.562500           0.589342         0.552868        0.034806
# 4             0.571875           0.567398         0.568480        0.029979
# ..                 ...                ...              ...             ...
# 139           0.596875           0.589342         0.582243        0.032150
# 140           0.571875           0.614420         0.582884        0.023934
# 141           0.562500           0.589342         0.573493        0.025575
# 142           0.571875           0.595611         0.575372        0.016384
# 143           0.593750           0.592476         0.584745        0.019895
#
#      rank_test_score
# 0                137
# 1                102
# 2                 89
# 3                144
# 4                131
# ..               ...
# 139               63
# 140               55
# 141              110
# 142               99
# 143               45
#
# [144 rows x 17 columns]
